# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %%
#Build the dictionary and replace rare words with UNK token.
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'originated', 'a', 'term', 'as', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['originated', 'term', 'a', 'anarchism', 'term', 'as', 'of', 'originated']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.849721
# Nearest to be: mcgill, fitz, net, bitten, activated, citizenship, pitchers, bouillon,
# Nearest to used: bolts, bg, cvs, polydor, behaviors, motorcyclists, franchisees, gametes,
# Nearest to b: monsignor, eof, greater, maclachlan, decree, cellists, reality, reaper,
# Nearest to been: regains, elevations, discuss, completed, inasmuch, nazism, proofs, situations,
# Nearest to into: nebulous, assessments, alfonso, sumner, horch, lamo, immanence, adequacy,
# Nearest to may: rhetoricians, clung, strolling, aussie, vonnegut, antiproton, luddites, cecil,
# Nearest to six: rrez, defensively, mario, manifesting, essai, bloc, penicillin, boating,
# Nearest to than: unoccupied, maj, kits, technik, irix, baylor, dearth, pancras,
# Nearest to which: vienne, geneticist, listens, litigation, chiapas, romanorum, heap, butt,
# Nearest to however: israelite, suspicions, embryo, gemara, handfasting, bulldog, commemorated, hogs,
# Nearest to from: levee, pavements, rupees, ligament, dactyl, hasan, chests, mycoplasma,
# Nearest to these: advocated, sellers, buckle, eliot, oo, accelerates, postulated, cutoff,
# Nearest to while: manna, hydrated, subjectivity, developmental, champions, rioting, diem, berle,
# Nearest to his: cathar, grafton, retire, antithesis, rpgs, bishopric, imran, paymaster,
# Nearest to th: spends, tiananmen, hattie, py, rosenzweig, labatt, misfortune, jinshi,
# Nearest to it: vcrs, joni, frazer, pavel, xliii, culturally, disregarding, customers,
# Average loss at step 2000: 4.368875
# Average loss at step 4000: 3.861915
# Average loss at step 6000: 3.789056
# Average loss at step 8000: 3.688432
# Average loss at step 10000: 3.616897
# Nearest to be: have, by, was, sentenced, is, fitz, make, verity,
# Nearest to used: gametes, healthy, diffeomorphic, sikh, blizzards, oren, atonement, houses,
# Nearest to b: d, auchinleck, slovakia, monsignor, uprising, greater, undertaking, eof,
# Nearest to been: discuss, tocantins, had, completed, regains, was, bec, outreach,
# Nearest to into: nebulous, from, immanence, assessments, as, slay, sumner, horch,
# Nearest to may: can, will, would, might, wingers, sitcom, unaccustomed, csf,
# Nearest to six: eight, four, seven, five, nine, three, zero, two,
# Nearest to than: maj, clothed, irix, consummated, dearth, pancras, macromedia, kits,
# Nearest to which: that, this, it, also, vassal, what, still, mod,
# Nearest to however: isa, eitc, hazlitt, must, afternoon, particulate, notate, samarium,
# Nearest to from: into, in, by, progress, honduras, intermediaries, through, eo,
# Nearest to these: all, charybdis, hpv, boucher, many, viktor, gallic, strangeness,
# Nearest to while: hydrated, manna, prerogative, but, diem, grail, berle, frantic,
# Nearest to his: their, the, s, her, its, this, pleasing, him,
# Nearest to th: six, tiananmen, spends, seven, py, denser, labatt, jinshi,
# Nearest to it: he, this, there, which, not, sainsbury, she, sanitarium,
# Average loss at step 12000: 3.607561
# Average loss at step 14000: 3.569679
# Average loss at step 16000: 3.409748
# Average loss at step 18000: 3.456866
# Average loss at step 20000: 3.543557
# Nearest to be: have, been, was, by, is, become, verity, make,
# Nearest to used: gametes, known, described, healthy, published, referred, viewed, found,
# Nearest to b: d, auchinleck, swedish, ludlow, precede, rpm, hebrew, intoxicated,
# Nearest to been: be, was, had, were, become, who, discuss, tocantins,
# Nearest to into: from, on, assessments, nebulous, within, slay, sensations, batasuna,
# Nearest to may: can, will, would, might, could, to, csf, wingers,
# Nearest to six: eight, seven, nine, five, four, three, zero, two,
# Nearest to than: or, irix, bots, pancras, aargau, maj, macromedia, kits,
# Nearest to which: this, that, who, it, what, also, there, still,
# Nearest to however: but, eitc, isa, must, gemara, landfill, hazlitt, afternoon,
# Nearest to from: into, in, through, between, fer, at, intermediaries, frankfort,
# Nearest to these: many, all, are, lactate, other, such, charybdis, the,
# Nearest to while: but, and, for, are, marsden, argues, if, marker,
# Nearest to his: their, her, its, the, locomotive, ideographic, antennae, shorthair,
# Nearest to th: denser, py, tiananmen, dimensional, templar, jinshi, spends, te,
# Nearest to it: he, there, this, they, she, which, sainsbury, not,
# Average loss at step 22000: 3.501902
# Average loss at step 24000: 3.494913
# Average loss at step 26000: 3.478805
# Average loss at step 28000: 3.479025
# Average loss at step 30000: 3.504175
# Nearest to be: been, have, is, write, are, was, become, verity,
# Nearest to used: known, described, able, gametes, referred, viewed, led, found,
# Nearest to b: d, auchinleck, ludlow, forrester, rpm, precede, single, soften,
# Nearest to been: be, was, become, were, had, circassians, discuss, inmates,
# Nearest to into: from, within, sensations, through, after, in, on, nebulous,
# Nearest to may: can, would, will, might, could, must, should, wingers,
# Nearest to six: eight, four, five, seven, nine, three, two, zero,
# Nearest to than: or, heron, lena, irix, striking, busby, dixie, writeups,
# Nearest to which: this, that, what, also, who, it, there, still,
# Nearest to however: but, although, if, when, while, which, that, must,
# Nearest to from: through, into, in, after, eo, between, within, of,
# Nearest to these: many, some, such, their, they, all, other, lactate,
# Nearest to while: but, although, if, however, are, where, when, during,
# Nearest to his: their, her, its, the, s, my, omphale, your,
# Nearest to th: six, rd, eight, denser, dimensional, te, zero, hepburn,
# Nearest to it: he, there, this, she, they, sainsbury, which, not,
# Average loss at step 32000: 3.501093
# Average loss at step 34000: 3.500242
# Average loss at step 36000: 3.448374
# Average loss at step 38000: 3.296493
# Average loss at step 40000: 3.429929
# Nearest to be: been, have, was, are, refer, were, is, being,
# Nearest to used: known, described, referred, found, responsible, seen, able, viewed,
# Nearest to b: d, auchinleck, UNK, floyd, c, bhopal, reaper, single,
# Nearest to been: become, be, was, were, gide, zaragoza, had, foraminifera,
# Nearest to into: from, through, within, sensations, slay, over, batasuna, dalglish,
# Nearest to may: can, would, will, might, could, must, should, cannot,
# Nearest to six: four, eight, seven, nine, five, three, two, zero,
# Nearest to than: or, heron, striking, lena, tribesmen, exeter, greenwich, dixie,
# Nearest to which: that, this, also, what, who, currently, there, still,
# Nearest to however: but, although, that, if, though, hitman, mithraism, when,
# Nearest to from: into, through, supervisor, after, between, fer, within, in,
# Nearest to these: many, some, both, those, they, such, several, their,
# Nearest to while: although, but, when, are, where, were, and, during,
# Nearest to his: their, her, its, my, the, your, s, several,
# Nearest to th: rd, six, te, denser, dimensional, billion, filesystems, tiananmen,
# Nearest to it: he, there, she, this, they, which, sainsbury, we,
# Average loss at step 42000: 3.437531
# Average loss at step 44000: 3.450401
# Average loss at step 46000: 3.455653
# Average loss at step 48000: 3.357369
# Average loss at step 50000: 3.383573
# Nearest to be: have, been, being, become, refer, is, was, cause,
# Nearest to used: known, described, referred, responsible, intended, available, considered, able,
# Nearest to b: d, auchinleck, wei, bhopal, visualisation, undecidability, reaper, rpm,
# Nearest to been: become, be, was, had, already, were, zaragoza, mashed,
# Nearest to into: through, from, within, sensations, on, slay, immanence, assessments,
# Nearest to may: can, would, will, might, could, should, must, cannot,
# Nearest to six: eight, seven, four, nine, five, three, zero, two,
# Nearest to than: or, heron, much, but, lena, launceston, while, striking,
# Nearest to which: that, this, who, also, what, now, dea, still,
# Nearest to however: but, although, that, when, while, though, where, which,
# Nearest to from: through, into, in, after, during, at, marshals, hexafluoride,
# Nearest to these: many, some, such, both, those, several, are, their,
# Nearest to while: although, when, but, after, however, though, where, anomalous,
# Nearest to his: her, their, its, my, your, the, him, them,
# Nearest to th: rd, te, five, six, eight, dimensional, one, radiology,
# Nearest to it: he, there, she, this, they, still, neither, ajiva,
# Average loss at step 52000: 3.441433
# Average loss at step 54000: 3.423023
# Average loss at step 56000: 3.440622
# Average loss at step 58000: 3.399548
# Average loss at step 60000: 3.392306
# Nearest to be: been, refer, become, is, being, have, was, were,
# Nearest to used: described, known, referred, seen, written, considered, intended, available,
# Nearest to b: d, auchinleck, c, bubba, m, f, e, floyd,
# Nearest to been: become, be, was, gide, already, mashed, were, had,
# Nearest to into: through, from, within, in, sensations, immanence, sous, slay,
# Nearest to may: can, would, will, could, might, should, must, cannot,
# Nearest to six: five, eight, four, nine, seven, three, zero, two,
# Nearest to than: or, much, and, cream, but, exeter, greenwich, lena,
# Nearest to which: that, this, what, however, there, who, dea, usually,
# Nearest to however: but, although, when, that, though, which, where, rinsing,
# Nearest to from: into, through, hexafluoride, in, within, eo, jstor, birthdate,
# Nearest to these: many, some, both, those, several, such, all, are,
# Nearest to while: although, when, after, though, before, anomalous, but, licensure,
# Nearest to his: her, their, its, my, your, the, our, shehri,
# Nearest to th: six, five, rd, eight, four, te, bc, klm,
# Nearest to it: there, he, she, this, they, often, we, not,
# Average loss at step 62000: 3.242173
# Average loss at step 64000: 3.259291
# Average loss at step 66000: 3.400874
# Average loss at step 68000: 3.400350
# Average loss at step 70000: 3.358610
# Nearest to be: been, become, is, are, were, being, have, refer,
# Nearest to used: known, seen, referred, described, written, responsible, found, available,
# Nearest to b: d, auchinleck, bubba, y, p, f, bhopal, h,
# Nearest to been: become, be, already, were, was, had, gide, mashed,
# Nearest to into: from, through, within, sensations, epitaph, thermally, sous, with,
# Nearest to may: can, will, would, could, might, should, must, cannot,
# Nearest to six: eight, seven, four, nine, five, three, zero, two,
# Nearest to than: or, much, cream, striking, tribesmen, exeter, but, dose,
# Nearest to which: that, this, what, however, but, usually, also, whitish,
# Nearest to however: but, although, though, that, while, when, which, where,
# Nearest to from: through, into, between, within, in, after, by, during,
# Nearest to these: such, many, some, those, are, their, the, adequacy,
# Nearest to while: although, though, including, however, when, before, after, where,
# Nearest to his: her, their, my, its, your, the, our, rescinded,
# Nearest to th: bc, rd, te, dimensional, klm, seven, six, eight,
# Nearest to it: he, she, there, this, they, we, still, which,
# Average loss at step 72000: 3.376493
# Average loss at step 74000: 3.349965
# Average loss at step 76000: 3.326225
# Average loss at step 78000: 3.352218
# Average loss at step 80000: 3.376754
# Nearest to be: been, have, being, become, refer, are, were, is,
# Nearest to used: known, referred, seen, described, found, written, responsible, available,
# Nearest to b: d, c, p, auchinleck, f, beti, bhopal, r,
# Nearest to been: become, be, already, were, was, zaragoza, cater, mashed,
# Nearest to into: through, from, within, shams, sensations, epitaph, dalglish, across,
# Nearest to may: can, would, might, could, will, should, must, cannot,
# Nearest to six: four, five, seven, eight, three, nine, two, zero,
# Nearest to than: or, much, while, consternation, aargau, writeups, tribesmen, and,
# Nearest to which: that, this, also, dea, what, usually, actually, currently,
# Nearest to however: but, although, that, though, while, when, sadie, especially,
# Nearest to from: through, into, within, after, in, hexafluoride, levee, under,
# Nearest to these: those, several, many, both, they, such, some, various,
# Nearest to while: although, though, after, and, when, before, however, including,
# Nearest to his: her, their, its, my, your, our, the, shehri,
# Nearest to th: bc, rd, te, eight, schwenkfeld, six, devry, bert,
# Nearest to it: he, there, she, this, they, we, still, not,
# Average loss at step 82000: 3.410151
# Average loss at step 84000: 3.414063
# Average loss at step 86000: 3.392071
# Average loss at step 88000: 3.357516
# Average loss at step 90000: 3.366619
# Nearest to be: become, been, have, being, refer, was, is, easily,
# Nearest to used: known, referred, seen, described, designed, considered, available, found,
# Nearest to b: d, c, f, auchinleck, cecil, beti, r, p,
# Nearest to been: become, be, already, was, were, mashed, zaragoza, being,
# Nearest to into: through, from, within, epitaph, sensations, bawdy, evenings, on,
# Nearest to may: can, could, would, might, will, should, must, cannot,
# Nearest to six: seven, eight, five, nine, four, three, two, zero,
# Nearest to than: consternation, much, or, aargau, no, tribesmen, allegedly, assigns,
# Nearest to which: that, this, what, also, but, actually, usually, dea,
# Nearest to however: but, although, that, though, especially, while, when, where,
# Nearest to from: through, into, under, during, levee, between, hexafluoride, after,
# Nearest to these: several, many, some, those, are, such, both, were,
# Nearest to while: although, though, after, when, before, were, during, however,
# Nearest to his: her, their, its, my, your, our, the, s,
# Nearest to th: seven, rd, bc, one, nine, eight, te, schwenkfeld,
# Nearest to it: he, she, there, this, they, sainsbury, itself, often,
# Average loss at step 92000: 3.399971
# Average loss at step 94000: 3.252264
# Average loss at step 96000: 3.355703
# Average loss at step 98000: 3.244450
# Average loss at step 100000: 3.355284
# Nearest to be: been, become, being, refer, have, is, are, easily,
# Nearest to used: known, referred, found, described, available, seen, responsible, designed,
# Nearest to b: d, swedish, french, auchinleck, undecidability, brainwashed, flaubert, onions,
# Nearest to been: be, become, already, was, yet, were, recently, zaragoza,
# Nearest to into: through, from, within, beet, back, bawdy, sensations, on,
# Nearest to may: can, could, might, would, should, must, will, cannot,
# Nearest to six: seven, four, five, eight, nine, three, two, zero,
# Nearest to than: or, much, consternation, and, aargau, allegedly, tribesmen, noma,
# Nearest to which: that, this, what, usually, actually, however, these, also,
# Nearest to however: but, although, especially, that, though, where, which, potentially,
# Nearest to from: through, into, in, during, eo, airtime, within, hexafluoride,
# Nearest to these: several, many, those, some, various, all, both, their,
# Nearest to while: although, when, though, and, after, where, before, but,
# Nearest to his: her, their, my, its, your, our, the, s,
# Nearest to th: bc, rd, te, nineteenth, schwenkfeld, ce, one, fifth,
# Nearest to it: he, she, this, there, they, sainsbury, often, what,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %%
data_index = 0

def generate_batch(batch_size, bag_window):
    global data_index
    span = 2 * bag_window + 1 # [ bag_window target bag_window ]
    batch = np.ndarray(shape=(batch_size, span - 1), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size):
        # just for testing
        buffer_list = list(buffer)
        labels[i, 0] = buffer_list.pop(bag_window)
        batch[i] = buffer_list
        # iterate to the next buffer
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:16]])

for bag_window in [1, 2]:
    data_index = 0
    batch, labels = generate_batch(batch_size=4, bag_window=bag_window)
    print('\nwith bag_window = %d:' % (bag_window))
    print('    batch:', [[reverse_dictionary[w] for w in bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(4)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the']
#
# with bag_window = 1:
#     batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of']]
#     labels: ['originated', 'as', 'a', 'term']
#
# with bag_window = 2:
#     batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first']]
#     labels: ['as', 'a', 'term', 'of']

# %%
batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
bag_window = 2  # How many words to consider left and right.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent.
valid_size = 16  # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64  # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):
    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size, bag_window * 2])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

    # Variables.
    embeddings = tf.Variable(
        tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],
                            stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))

    # Model.
    # Look up embeddings for inputs.
    embeds = tf.nn.embedding_lookup(embeddings, train_dataset)
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(
        tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, tf.reduce_sum(embeds, 1),
                                   train_labels, num_sampled, vocabulary_size))

    # Optimizer.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)

    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(
        normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-55-ca659c2eae87> in <module>()
#      32     loss = tf.reduce_mean(
#      33         tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, tf.reduce_sum(embeds, 1),
# ---> 34                                    train_labels, num_sampled, vocabulary_size))
#      35
#      36     # Optimizer.
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/ops/nn_impl.pyc in sampled_softmax_loss(weights, biases, labels, inputs, num_sampled, num_classes, num_true, sampled_values, remove_accidental_hits, partition_strategy, name)
#    1254       remove_accidental_hits=remove_accidental_hits,
#    1255       partition_strategy=partition_strategy,
# -> 1256       name=name)
#    1257   sampled_losses = nn_ops.softmax_cross_entropy_with_logits(
#    1258       labels=labels, logits=logits)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/ops/nn_impl.pyc in _compute_sampled_logits(weights, biases, labels, inputs, num_sampled, num_classes, num_true, sampled_values, subtract_log_q, remove_accidental_hits, partition_strategy, name)
#     988     # sampled_w has shape [num_sampled, dim]
#     989     # Apply X*W', which yields [batch_size, num_sampled]
# --> 990     sampled_logits = math_ops.matmul(inputs, sampled_w, transpose_b=True)
#     991
#     992     # Retrieve the true and sampled biases, compute the true logits, and
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/ops/math_ops.pyc in matmul(a, b, transpose_a, transpose_b, adjoint_a, adjoint_b, a_is_sparse, b_is_sparse, name)
#    1889     else:
#    1890       return gen_math_ops._mat_mul(
# -> 1891           a, b, transpose_a=transpose_a, transpose_b=transpose_b, name=name)
#    1892
#    1893
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/ops/gen_math_ops.pyc in _mat_mul(a, b, transpose_a, transpose_b, name)
#    2435     _, _, _op = _op_def_lib._apply_op_helper(
#    2436         "MatMul", a=a, b=b, transpose_a=transpose_a, transpose_b=transpose_b,
# -> 2437         name=name)
#    2438     _result = _op.outputs[:]
#    2439     _inputs_flat = _op.inputs
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/framework/op_def_library.pyc in _apply_op_helper(self, op_type_name, name, **keywords)
#     544                   "%s type %s of argument '%s'." %
#     545                   (prefix, dtypes.as_dtype(attrs[input_arg.type_attr]).name,
# --> 546                    inferred_from[input_arg.type_attr]))
#     547
#     548           types = [values.dtype]
#
# TypeError: Input 'b' of 'MatMul' Op has type float32 that does not match type int32 of argument 'a'.
